# %%
def FindPossibilities(name,info) :
    #print(a_dictionary)
    #values = [value for value in a_dictionary.values() if name in value]
    output = []
    output.append(name)
    while True :
        
        find = False
        msg = ''
        msg = "*only*"
        timestage = 0
        temp = ''
        c = ''
        ind = 1
        for x, y in a_dictionary.items():
            c =  info.split('-')[1]
            timestage = int(c)-ind
            if(y.count(name) == 1 and x.split(' ')[1] ==  str(timestage)) :
                #print (x.split(' ')[1])
                #print(x, y)
                #print (msg)
                find = True
        if(find == False ) :
            for x, y in a_dictionary.items():
                c = info.split('-')[1]
                timestage = int(c) -(ind+1)
                if(y.count(name) == 1 and x.split(' ')[1] ==  str(timestage)) :
                    #print (x.split(' ')[1])
                    #print(x, y)
                    temp = y.replace(name,'')
                    if(len(temp) == 1) :
                        #print(temp)
                        output.append(temp)
                    name = temp
                    break
        
        name = temp
        if(find == False) or (ind == 2 ):
            print("Cannot go to the destination")
            break
        elif(find == True) :
            print(''.join(output))
            break
        
        
        ind += 1
                
                
a_dictionary = {}
def ElevatorClimbingPossibilities(path) :
    a = []
    a = path.split(' ')
    name = a[1]
    info = a[2]
    a_file = open(a[0])
    
    
    ind = 0
    state = 0
    for line in a_file:
        line = line.replace('x','').replace('.','').replace('\n','')
        a_dictionary[str(ind) + ' ' + str(state)] = line
        if(ind%6 == 0) and ind != 0 :
            state = ind//6 
        ind += 1
        #print(a_dictionary)
    
    FindPossibilities(name,info)  
        
        
path = '' 
path = "elevators.txt A 3-2"
ElevatorClimbingPossibilities (path)

# %%
import pandas as pd
a_dictionary = {}
def ElevatorClimbingPossibilities(path) :
    a = []
    a = path.split(' ')
    name = a[1]
    info = a[2]
    a_file = open(a[0])
    
    
    ind = 0
    state = 0
    for line in a_file:
        line = line.replace('x','').replace('.','').replace('\n','')
        a_dictionary[str(ind) + ' ' + str(state)] = line
        if(ind%6 == 0) and ind != 0 :
            state = ind//6 
        ind += 1
        #print(a_dictionary)
    
    ser = pd.Series(data= ','.join(a_dictionary.keys()), index=['a'])
    print(ser.head(10))    
        
path = '' 
path = "elevators.txt A 3-2"
ElevatorClimbingPossibilities (path)

# %%
from pandas import DataFrame
import pandas as pd
import os
path = '' 
path = "elevators.txt A 3-2"
filepath = ''
filepath = path.split(' ')
row = 0
with open(filepath[0]) as f:
    #df = pd.DataFrame(f)
    df2 = DataFrame(columns =["Name"])
    for line in f:
        data = line.replace('x','').replace('.','').replace('\n','')
        
        #row,column,value = row,0,data
        df2 = df2.append({'Name': data}, ignore_index=True)  
        row += 1
print (df2)
print(df)
pd.

# %%
import pyodbc
import pandas as pd
#import DataSet
# Some other example server values are
# server = 'localhost\sqlexpress' # for a named instance
# server = 'myserver,port' # to specify an alternate port
#Server=localhost\SQLEXPRESS;Database=master;Trusted_Connection=True;
server = 'localhost\SQLEXPRESS' 
database = 'master' 
username = 'narah' 
password = ''  
cnxn = pyodbc.connect('Driver={SQL Server};' 'Server=LAPTOP-AI7V9DQF\SQLEXPRESS;' 'Database=AdventureWorksLT2019;' 'Trusted_Connection=Yes;')
#cnxn = pyodbc.connect('Server=LAPTOP-AI7V9DQF\SQLEXPRESS;' 'Database=AdventureWorksLT2019;' 'Trusted_Connection=Yes;')
cursor = cnxn.cursor()
# select 26 rows from SQL table to insert in dataframe.
query = "select s.FirstName from SALESLT.CUSTOMER  s;"
df = pd.read_sql(query, cnxn)
print(df.head(26))
df.count()
##for i in df.items() :
  #  print(i)
df.selecttName == 'Lucy')

# %%
# Import package
from pydataset import data
# Check out datasets
data()

# %%
import sys  
#!{sys.executable} -m pip i --trusted-host pypi.python.org linkchecker
# !{sys.executable} -m pip install pydataset
