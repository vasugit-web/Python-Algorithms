# %%
def removeDuplicates(nums) -> int:
    l = 1
    for i in range(0,len(nums)-1) :
        if(nums[i] != nums[i+1]):
            l+=1
            nums[i] = nums[i+1]

    print(nums)       
    return l

# %%
# Given an array, rotate the array to the right by k steps, where k is non-negative.

 

# Example 1:

# Input: nums = [1,2,3,4,5,6,7], k = 3
# Output: [5,6,7,1,2,3,4]
# Explanation:
# rotate 1 steps to the right: [7,1,2,3,4,5,6]
# rotate 2 steps to the right: [6,7,1,2,3,4,5]
# rotate 3 steps to the right: [5,6,7,1,2,3,4]


def rotate(nums, k) -> None:
    """
    Do not return anything, modify nums in-place instead.
    """
    k %= len(nums)
    #print (k)
    for i in range(k):
        previous = nums[-1]
        for j in range(len(nums)):
            nums[j], previous = previous, nums[j]

# %%
# Given an integer array nums, return true if any value appears at least twice in the array, and return false if every element is distinct.

 

# Example 1:

# Input: nums = [1,2,3,1]
# Output: true

def containsDuplicate(nums) -> bool:
    l1 = len(nums)
    if(1 <= l1 <= pow(10,5) and -pow(10,9) <= l1 <= pow(10,9)) :
        l = [k  for k in nums if nums.count(k) > 1 ]

        if(len(l)) > 0 :
            return True

    else:
        return False

# %%
def singleNumber(nums: List[int]) -> int:
    l1 = len(nums)
    if(1 <= l1 <= 3 * pow(10,4) ) :
        l =  [x for x in nums if(nums.count(x) ==1 and (-3 * pow(10,4) <= x <= 3 * pow(10,4) ))]
        print(l)
        if(len(l) == 1) :
            return l[0]

# %%
# Given two integer arrays nums1 and nums2, return an array of their intersection. Each element in the result must appear as many times as it shows in both arrays and you may return the result in any order.
# Example 1:
# Input: nums1 = [1,2,2,1], nums2 = [2,2]
# Output: [2,2]
def intersect(nums1 , nums2 ):
    if(len(nums1) >= 1 and len(nums2) <= 1000 ) :

        if(len(nums1) >= len(nums2)) :
            d1 = [i for i in nums2 if(nums1.count(i) > 0  and 0 <= i and i <= 1000)]
        elif(len(nums1) <= len(nums2)) : 
             d1 = [i for i in nums1 if(nums2.count(i) > 0  and 0 <= i and i <= 1000)]
        else :
            d1 = [i for i in nums2 if(nums1.count(i) > 0  and 0 <= i and i <= 1000)]


        return list(d1)

# %%
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
# You can return the answer in any order.
# Example 1:
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
def twoSum(nums , target: int) :
    
    r = []
    if 2 <= len(nums) <= pow(10,4) and -pow(10,9) <= target <= pow(10,9) and  len([i for i in nums if(-pow(10,9) <= i <= pow(10,9))]) == len(nums) :

        for i in range(len(nums)) :
            for j in range(i+1,len(nums)) :
                #print(nums[i] ,nums[j] )
                if(nums[j] + nums[i]== target) :
                    r.append(i)
                    r.append(j)
                    break
    return r

# %%
# Given an integer array nums, move all 0's to the end of it while maintaining the relative order of the non-zero elements.

# Note that you must do this in-place without making a copy of the array.

 

# Example 1:

# Input: nums = [0,1,0,3,12]
# Output: [1,3,12,0,0]
def moveZeroes(nums) -> None:
    """
    Do not return anything, modify nums in-place instead.
    """
    # l = len(nums)
    # i,j = l-1,0
    # while(j <= i) :
    #     print(i,j)
    #     if(nums[j] == 0) :
    #         nums[i],nums[j] = nums[j],nums[i]
    #     i-=1
    #     j+=1
    pos = 0

    for i in range(len(nums)):
        el = nums[i]
        if el != 0:
            nums[pos], nums[i] = nums[i], nums[pos]
            pos += 1
